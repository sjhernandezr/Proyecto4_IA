# %%
import pandas as pd
lasso_mejor = {
    'Algoritmo': 'Lasso Regression',
    'Tipo': 'Regresión',
    'Hiperparámetros': "alpha=0.001, max_iter=1000, tol=0.001",
    'Métrica principal': 'R²',
    'Valor métrica': 0.750812,
    'Error': 'MSE',
    'Valor error': 112.617358
}

decision_tree_mejor = {
    'Algoritmo': 'DecisionTreeRegressor',
    'Tipo': 'Regresión',
    'Hiperparámetros': "max_depth=11, min_samples_split=5, min_samples_leaf=8",
    'Métrica principal': 'R² (validación)',
    'Valor métrica': 0.698670,
    'Error': 'RMSE (validación)',
    'Valor error': 11.707738
}

kmeans_mejor = {
    'Algoritmo': 'K-Means',
    'Tipo': 'Clustering',
    'Hiperparámetros': "n_clusters=5, init='random', max_iter=300",
    'Métrica principal': 'Silhouette',
    'Valor métrica': 0.277033,
    'Error': '—',
    'Valor error': '—'
}
summary_df = pd.DataFrame([lasso_mejor, decision_tree_mejor, kmeans_mejor])
summary_df
# Out:
#                Algoritmo        Tipo  \
# 0       Lasso Regression   Regresión
# 1  DecisionTreeRegressor   Regresión
# 2                K-Means  Clustering
#
#                                      Hiperparámetros Métrica principal  \
# 0              alpha=0.001, max_iter=1000, tol=0.001                R²
# 1  max_depth=11, min_samples_split=5, min_samples...   R² (validación)
# 2          n_clusters=5, init='random', max_iter=300        Silhouette
#
#    Valor métrica              Error Valor error
# 0       0.750812                MSE  112.617358
# 1       0.698670  RMSE (validación)   11.707738
# 2       0.277033                  —           —

# %% [markdown]
# Se probaron tres algoritmos: Lasso Regression, DecisionTreeRegressor y K-Means, de los tres, el que tuvo mejor desempeño fue Lasso Regression, con un R² de 0.75, lo que significa que logra explicar bien la mayoría de la variación de los datos, aunque su error MSE fue algo alto, por otro lado, el árbol de decisión también tuvo un resultado aceptable, con un R² de 0.69, pero es un modelo que puede sobreajustarse fácilmente si no se ajustan bien sus parámetros, en cambio, el K-Means, que se usó para agrupar los datos, tuvo un valor de Silhouette de 0.27, lo que indica que los grupos formados no están bien separados, así que no fue muy efectivo en este caso y en general, el mejor modelo fue el de Lasso, y para mejorar los resultados en futuros intentos se podrían ajustar mejor los hiperparámetros, normalizar los datos, probar nuevos modelos como Random Forest o Gradient Boosting, y usar validación cruzada para obtener métricas más confiables.
