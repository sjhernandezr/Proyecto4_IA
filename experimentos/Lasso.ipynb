# %% [markdown]
# Limpieza de datos requerida para que el algoritmo funcione

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import joblib
df = pd.read_csv('../datos/Food_Delivery_Times.csv')

cols = ['Distance_km','Preparation_Time_min','Courier_Experience_yrs']
X = df[cols]
y = df['Delivery_Time_min'].astype(float)

mask = X.notna().all(axis=1) & y.notna()
X = X[mask]
y = y[mask]

clf = linear_model.Lasso(alpha=0.1, random_state=42)
clf.fit(X, y)

print(clf.coef_)
print(clf.intercept_)

train_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
test_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
validation_df = pd.read_csv('../datos/Food_Delivery_Times.csv')

train_x = train_df.drop(columns="")
train_y = train_df['']
test_x = test_df.drop(columns=[])
test_y = test_df['']
validation_x = validation_df.drop(colunmns = [''])
validation_y = validation_df['']
# Out:
# [ 3.0238142   0.95856276 -0.5537646 ]
# 12.578621464012521
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 26
#      23 test_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
#      24 validation_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
# ---> 26 train_x = train_df.drop(columns="")
#      27 train_y = train_df['']
#      28 test_x = test_df.drop(columns=[])
#
# File ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "[''] not found in axis"

# %% [markdown]
# Error que se medirá en el algoritmo lasso:
#  MSE: este error calcula la diferencia entre un valor real y un valor estimado o predicho, mide que tan diferentes son los unos de los otro
#  se usa en lasso porque dicho algoritmo minimiza el error cuadratico

# %% [markdown]
# Variable dependiente: minutos que se demora la entrega.
# Variables independientes: distancia.
# factores controlables: Vehicle_Type,Preparation_Time_min, distance
# factores no-controlables: weather, traffic_level

# %% [markdown]
# hiper-parametros:
# alpha: fuerza de la penalización [0.001, 0.01, 0.1]
# max_iter: numero de iteraciones [1000, 5000, 10000]
# tol:  tolerancia de parada [1e-3, 1e-4, 1e-5]

# %%
results = []
alpha_values = [0.001, 0.01, 0.1]
max_iter_values = [1000,2000,3000]
tol_values = [1e-3, 1e-4, 1e-5]

# %%
for alpha in alpha_values:
    for max_iter in max_iter_values:
        for tol in tol_values:
            model = Lasso(alpha=alpha, max_iter=max_iter, tol=tol) 
    model.fit (train_x,  train_y)

    validation_pred = model.predict(validation_x)
    mse = mean_squared_error(validation_y, validation_pred)
    r2 = r2_score(validation_y, validation_pred)

    results.append({
        'alpha' : alpha,
        'max_iter' : max_iter,
        'tol': tol,
        'MSE': mse,
        'R2' : r2
    })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for alpha in alpha_values:
#       2     for max_iter in max_iter_values:
#       3         for tol in tol_values:
#
# NameError: name 'alpha_values' is not defined

# %%
results_df = pd.DataFrame(results)
results_df
