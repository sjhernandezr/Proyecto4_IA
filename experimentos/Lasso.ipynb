# %% [markdown]
# Limpieza de datos requerida para que el algoritmo funcione

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import joblib
df = pd.read_csv('../datos/Food_Delivery_Times.csv')

cols = ['Distance_km','Preparation_Time_min','Courier_Experience_yrs']
X = df[cols]
y = df['Delivery_Time_min'].astype(float)

mask = X.notna().all(axis=1) & y.notna()
X = X[mask]
y = y[mask]

clf = linear_model.Lasso(alpha=0.1, random_state=42)
clf.fit(X, y)

print(clf.coef_)
print(clf.intercept_)

train_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
test_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
validation_df = pd.read_csv('../datos/Food_Delivery_Times.csv')
target = 'Delivery_Time_min'
drop_cols = [target, 'Order_ID']  

train_x = train_df.drop(columns=drop_cols, errors='ignore')
train_y = train_df[target]

test_x = test_df.drop(columns=drop_cols, errors='ignore')
test_y = test_df[target]

validation_x = validation_df.drop(columns=drop_cols, errors='ignore')
validation_y = validation_df[target]
# Out:
# [ 3.0238142   0.95856276 -0.5537646 ]
# 12.578621464012521

# %% [markdown]
# Error que se medirá en el algoritmo lasso:
#  MSE: este error calcula la diferencia entre un valor real y un valor estimado o predicho, mide que tan diferentes son los unos de los otro
#  se usa en lasso porque dicho algoritmo minimiza el error cuadratico

# %% [markdown]
# Variable dependiente: minutos que se demora la entrega.
# Variables independientes: distancia.
# factores controlables: Vehicle_Type,Preparation_Time_min, distance
# factores no-controlables: weather, traffic_level

# %% [markdown]
# hiper-parametros:
# alpha: fuerza de la penalización [0.001, 0.01, 0.1]
# max_iter: numero de iteraciones [1000, 5000, 10000]
# tol:  tolerancia de parada [1e-3, 1e-4, 1e-5]

# %%
results = []
alpha_values = [0.001, 0.01, 0.1]
max_iter_values = [1000,2000,3000]
tol_values = [1e-3, 1e-4, 1e-5]

# %%
for alpha in alpha_values:
    for max_iter in max_iter_values:
        for tol in tol_values:
            model = Lasso(alpha=alpha, max_iter=max_iter, tol=tol) 
    model.fit (train_x,  train_y)

    validation_pred = model.predict(validation_x)
    mse = mean_squared_error(validation_y, validation_pred)
    r2 = r2_score(validation_y, validation_pred)

    results.append({
        'alpha' : alpha,
        'max_iter' : max_iter,
        'tol': tol,
        'MSE': mse,
        'R2' : r2
    })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2r/kzsmxt8514g5z5wxh99tntqw0000gn/T/ipykernel_3902/2622235900.py in ?()
#       1 for alpha in alpha_values:
#       2     for max_iter in max_iter_values:
#       3         for tol in tol_values:
#       4             model = Lasso(alpha=alpha, max_iter=max_iter, tol=tol)
# ----> 5     model.fit (train_x,  train_y)
#       6
#       7     validation_pred = model.predict(validation_x)
#       8     mse = mean_squared_error(validation_y, validation_pred)
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py in ?(self, X, y, sample_weight, check_input)
#     982         # We expect X and y to be float64 or float32 Fortran ordered arrays
#     983         # when bypassing checks
#     984         if check_input:
#     985             X_copied = self.copy_X and self.fit_intercept
# --> 986             X, y = validate_data(
#     987                 self,
#     988                 X,
#     989                 y,
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2967             if "estimator" not in check_y_params:
#    2968                 check_y_params = {**default_check_params, **check_y_params}
#    2969             y = check_array(y, input_name="y", **check_y_params)
#    2970         else:
# -> 2971             X, y = check_X_y(X, y, **check_params)
#    2972         out = X, y
#    2973
#    2974     if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364         )
#    1365
#    1366     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1367
# -> 1368     X = check_array(
#    1369         X,
#    1370         accept_sparse=accept_sparse,
#    1371         accept_large_sparse=accept_large_sparse,
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# ~/Desktop/Proyecto4_IA/venvv/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Windy'

# %%
results_df = pd.DataFrame(results)
results_df
